# %%
from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import StratifiedKFold

# %%
from sklearn.model_selection import KFold

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import KFold,train_test_split
from sklearn import svm
from sklearn.preprocessing import LabelEncoder,MinMaxScaler,StandardScaler

import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9462714b-8462-420f-b9de-673f90be2100" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9462714b-8462-420f-b9de-673f90be2100">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving colon_microarray.csv to colon_microarray.csv

# %%
dataset=pd.read_csv('colon_microarray.csv')

# %%
dataset.drop(axis=1,columns=[dataset.columns[0]],inplace=True)

# %%
l=LabelEncoder()
y=l.fit_transform(dataset.iloc[:,-1]) #the class column
y.shape
# Out:
# (62,)

# %%
x=dataset.iloc[:,:-1]

# %%
x
# Out:
#        H55933     R39465    R39465_  ...     H40891    R77780    T49647
# 0   8589.4160  5468.2407  4263.4077  ...   75.67750  83.52250  28.70125
# 1   9164.2540  6719.5293  4883.4487  ...  186.56750  44.47250  16.77375
# 2   3825.7050  6970.3613  5369.9688  ...   42.65625  16.09250  15.15625
# 3   6246.4487  7823.5340  5955.8350  ...   42.52000  49.98250  16.08500
# 4   3230.3286  3694.4500  3400.7400  ...   57.59875   7.48875  31.81250
# ..        ...        ...        ...  ...        ...       ...       ...
# 57  4972.1660  4173.9180  3668.5337  ...   57.15250  13.96000  10.54750
# 58  9112.3720  6824.4863  5982.8460  ...  106.87875  23.20250  32.16625
# 59  6730.6250  3472.1250  2559.4624  ...  133.52126  93.09875   7.43250
# 60  6234.6226  4005.3000  3093.6750  ...  118.20125  32.68750  23.26500
# 61  7472.0100  3653.9340  2728.2163  ...   77.21500  49.86250  39.63125
#
# [62 rows x 2000 columns]

# %% [markdown]
# #normalizing the data using minmaxscaler

# %%
x=pd.DataFrame(MinMaxScaler().fit_transform(x))

# %%
x.shape
# Out:
# (62, 2000)

# %%
x.head()
# Out:
#        0         1         2     ...      1997      1998      1999
# 0  0.514957  0.465829  0.408125  ...  0.181354  0.405899  0.189117
# 1  0.559306  0.608527  0.492652  ...  0.469349  0.201852  0.090550
# 2  0.147436  0.637132  0.558977  ...  0.095594  0.053559  0.077184
# 3  0.334197  0.734429  0.638846  ...  0.095240  0.230644  0.084859
# 4  0.101503  0.263544  0.290522  ...  0.134401  0.008602  0.214827
#
# [5 rows x 2000 columns]

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
r=x.shape[0]#62
c=x.shape[1]#2000
train_indices=np.arange(1, r, 4)#16
test_indices=np.arange(0, r, 4)#16

# %%
#describes each gene
class Chromosome:
  def __init__(self):
    self.chromosome=np.zeros(c)
    for i in range(50):
      random_row_no=np.random.randint(0,c)
      self.chromosome[random_row_no]=1
      

    #put code to intialise a gene
  
  def tupletolist(self,arr):
    ret=[]
    for i in arr:
      ret.append(i)
    return ret

  def fitnessfunc(self):
    model= svm.SVC(kernel='linear', C=2)
    arr=np.nonzero(self.chromosome)
    ret=self.tupletolist(arr[0])
    x_train,x_test,y_train,y_test=train_test_split(x.iloc[:,ret],y,test_size=0.3)
    m=model.fit(x_train,y_train)
    predicted_y = model.predict(x_test)
    return(accuracy_score(y_test,predicted_y)/len(arr))

  def fitness(self):
    kf5 = KFold(n_splits=5, shuffle=False)

# %%
ch=Chromosome()
ch.fitnessfunc()
# Out:
# 0.8421052631578947

# %%
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         #gives the selection crossover mutation operators and a function to return current best gene
class GA:
  def __init__(self,k=10):
    #k is the population size
    self.p=list() # p is the list of chromosomes in the population
    for i in range(k):
      self.p.append(Chromosome())

  #returns the best chromosome in the population at current moment
  def best_chromosome(self):
    mf=self.p[0].fitnessfunc()
    bestGene=0
    for j in self.p:
      x=j.fitnessfunc()
      if x>mf:
        mf=x
        bestGene=j
    return j
  
  def best_fitness(self):
    m=self.p[0].fitnessfunc()
    for i in self.p:
      ij=i.fitnessfunc()
      if ij>m:
        m=ij
    return m

 
  #updates which are selected to go to next generation
  def selection(self,k=10):
    #k chromosomes selected in random and the best candidate is chosen for next generation
    ans=self.cal_fitness_population()
    population_size=len(self.p)
    selec=[]
    #selecting 50% of the population for crossover and mutation,deleting the rest
    while(len(selec)<population_size):
      r=[]# r=list of k chromosomes from current population
      for i in range(k):
        r.append(np.random.randint(0,len(self.p)))
      m=ans[r[0]] #m saves max fitness
      mc=r[0]
       #saves selected chromosome no.
      for g in r:
        if ans[g]>m:
          m=ans[g]
          mc=g
      selec.append(g)
    return(selec)# return list of selected chromosome
  
  
    
  def crossover(self):
    num_parents_mating=len(self.p)
    elitism=0 #number of parents to protect
    offspring_size=len(self.p)-elitism# same number of children are to be produced as many chromosomes 
    
    #no of offspring=total size of population-no of parents: 5
    offspring=[0]*offspring_size
    crossover_point=np.random.randint(0,c)#the point where crossover will occur
    #for each offspring
    for k in range(offspring_size):
      # select two parents
      p1=k%num_parents_mating
      p2=(k+1)%num_parents_mating
      offspring[k]=Chromosome()
      offspring[k].chromosome[0:crossover_point]=self.p[parents[p1]].chromosome[0:crossover_point]
      offspring[k].chromosome[crossover_point:]=self.p[parents[p2]].chromosome[crossover_point:]
      # print("fitness of offspring: ",k,":",offspring[k].fitnessfunc())
    self.p=offspring
   # return offspring
 

  
  # 3 types of mutation possible(bit flip at one random point,swap any two random bits,inverse of a subset of bits)
  def mutation(self,mutation_rate=0.2,mutation_type=1):
    for i in range(len(self.p)):
      # print("offspring ",i,"from:",offsprings[i].fitnessfunc())
      if np.random.uniform()>=mutation_rate:# by default keeping probability of a chromosome getting mutated as 0.2
        if mutation_type==1:  #bit flip mutation
          random_no=np.random.randint(0,c)
          if self.p[i].chromosome[random_no]==1:
            self.p[i].chromosome[random_no]=0
          else:
            self.p[i].chromosome[random_no]=1
      

  def cal_fitness_population(self):
    ans=[]
    for i in self.p:
      ans.append(i.fitnessfunc())
    return ans

# %%
sol_per_population = 10# Population size.
num_parents_mating = sol_per_population//2 # Number of parents inside the mating pool.
#num_mutations = 3 # Number of elements to mutate.

# %%
#initial population
population_shape=(sol_per_population,c)
#new_population=np.random.randint(low=0, high=2, size=population_shape)
#new_population
mutation_rate=0.3

# %%
if __name__ == "__main__":
  
  obj=GA(sol_per_population)#creating a population of 10 particles
  maxIter=10   #no. of generations
  # print("Enter muation type 1/2/3")
  # mt=int(input())
  mt=1
  for i in range(maxIter):
    fitnes=obj.cal_fitness_population()
   
    print("Fitness of gen ",i," is ",fitnes)
    print("Best fitness of gen ",i, "is ",obj.best_fitness())
    print("Best particle of gen",i,' is ',np.nonzero(obj.best_chromosome().chromosome))
    print("\n\n\n")
    if obj.best_fitness()>0.99:
      break

  
    parents=obj.selection()#parents saves the chromosome indexed selected
    # print("#parents: ",len(parents))
    #updating the entire population to only selected chromosomes,the fittest chromosomes apear more than once in the new population
    newpop=[]
    for i in parents:
      newpop.append(obj.p[i])
    obj.p=newpop
    
    #applying cross over and mutation on entire population respectively
    obj.crossover()
    obj.mutation()
   
    


  print("Best chromosome: ",obj.best_chromosome().fitnessfunc())
  print("Chromosome: ",obj.best_chromosome().chromosome)
# Out:
# Fitness of gen  0  is  [0.8421052631578947, 0.7894736842105263, 0.7894736842105263, 0.8947368421052632, 0.6842105263157895, 0.8947368421052632, 0.631578947368421, 0.6842105263157895, 0.7368421052631579, 0.7368421052631579]
# Best fitness of gen  0 is  0.9473684210526315
# Best particle of gen 0  is  (array([  27,   31,   40,   60,   90,   99,  263,  339,  351,  364,  381,
#         468,  471,  510,  513,  548,  611,  625,  675,  710,  739,  767,
#         794,  845,  924,  932,  950,  990, 1013, 1037, 1076, 1079, 1144,
#        1176, 1185, 1221, 1270, 1287, 1301, 1368, 1459, 1763, 1783, 1841,
#        1919, 1933, 1942, 1987, 1993]),)
#
#
#
#
# Fitness of gen  1  is  [0.7894736842105263, 0.7894736842105263, 0.7894736842105263, 0.6842105263157895, 0.8947368421052632, 0.631578947368421, 0.8421052631578947, 0.7894736842105263, 0.7368421052631579, 0.631578947368421]
# Best fitness of gen  1 is  0.8947368421052632
# ...
